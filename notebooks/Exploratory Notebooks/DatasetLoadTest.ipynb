# %%
from ssapp.data.AntennaDatasetLoaders import MLADataset1, ReflectorCutDataset2
from torch.utils.data.dataloader import DataLoader  
from ssapp.data.AntennaDatasetLoaders import load_serialized_dataset
from ssapp.Utils import FigureSaver

# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']
# %load_ext autoreload
# %autoreload 2



dataset = load_serialized_dataset('ReflectorCutDataset2')

params, fields = next(iter(DataLoader(dataset, batch_size=len(dataset))))

figSaver = FigureSaver(subfolder= )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# torch.Size([360, 361, 3, 4])

# %%
#print(params)
from matplotlib import pyplot as plt
import numpy as np
import plotly.express as pltexp
from ssapp.visualization.data_visualisation import plot_dataset_field_example

plot_dataset_field_example(dataset,100,ylim=[-100,40])
